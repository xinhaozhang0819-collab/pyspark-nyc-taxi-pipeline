# %% [markdown]
# # Step A: Load 2019 Yellow Taxi Sample (Development Dataset)

# %% [markdown]
# Loaded 4.6 GB NYC Yellow Taxi dataset from Databricks public datasets for distributed processing.

# %%
# For TEST ONLY
base = "dbfs:/databricks-datasets/nyctaxi/tripdata/yellow"
files = dbutils.fs.ls(base)
paths_2019_01 = [f.path for f in files if "2019-01" in f.name]

df_dev = (spark.read
              .option("header", "true")
              .option("inferSchema", "true")
              .csv(paths_2019_01))

df_dev.printSchema()
df_dev.show(5)
# Out:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp (nullable = true)
#  |-- passenger_count: integer (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: integer (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: integer (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+
# |       1| 2019-01-01 00:46:40|  2019-01-01 00:53:20|              1|          1.5|         1|                 N|         151|         239|           1|        7.0|  0.5|    0.5|      1.65|         0.0|                  0.3|        9.95|                NULL|
# |       1| 2019-01-01 00:59:47|  2019-01-01 01:18:59|              1|          2.6|         1|                 N|         239|         246|           1|       14.0|  0.5|    0.5|       1.0|         0.0|                  0.3|        16.3|                NULL|
# |       2| 2018-12-21 13:48:30|  2018-12-21 13:52:40|              3|          0.0|         1|                 N|         236|         236|           1|        4.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         5.8|                NULL|
# |       2| 2018-11-28 15:52:25|  2018-11-28 15:55:45|              5|          0.0|         1|                 N|         193|         193|           2|        3.5|  0.5|    0.5|       0.0|         0.0|                  0.3|        7.55|                NULL|
# |       2| 2018-11-28 15:56:57|  2018-11-28 15:58:33|              5|          0.0|         2|                 N|         193|         193|           2|       52.0|  0.0|    0.5|       0.0|         0.0|                  0.3|       55.55|                NULL|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+
# only showing top 5 rows

# %%
# === Load Full Dataset (2017–2020) ===
base = "dbfs:/databricks-datasets/nyctaxi/tripdata/yellow"
files = dbutils.fs.ls(base)

subset_full = [f.path for f in files if any(y in f.name for y in ["2017", "2018", "2019", "2020"])]

df_dev = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(subset_full)
)

df_dev.printSchema()
df_dev.show(5)
print(f"Loaded full dataset with {df_dev.count():,} rows")
# Out:
# root
#  |-- VendorID: string (nullable = true)
#  |-- tpep_pickup_datetime: string (nullable = true)
#  |-- tpep_dropoff_datetime: string (nullable = true)
#  |-- passenger_count: string (nullable = true)
#  |-- trip_distance: string (nullable = true)
#  |-- RatecodeID: string (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: string (nullable = true)
#  |-- DOLocationID: string (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- fare_amount: string (nullable = true)
#  |-- extra: string (nullable = true)
#  |-- mta_tax: string (nullable = true)
#  |-- tip_amount: string (nullable = true)
#  |-- tolls_amount: string (nullable = true)
#  |-- improvement_surcharge: string (nullable = true)
#  |-- total_amount: string (nullable = true)
#
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+
# |       1| 2017-10-01 00:01:50|  2017-10-01 00:14:13|              1|         2.00|         1|                 N|         142|         233|           2|         10|  0.5|    0.5|         0|           0|                  0.3|        11.3|
# |       1| 2017-10-01 00:02:43|  2017-10-01 00:08:35|              2|         2.30|         1|                 N|         142|         166|           1|          8|  0.5|    0.5|      1.85|           0|                  0.3|       11.15|
# |       1| 2017-10-01 00:12:08|  2017-10-01 00:25:49|              3|         2.80|         1|                 N|         151|         262|           1|         13|  0.5|    0.5|      1.72|           0|                  0.3|       16.02|
# |       2| 2017-10-01 00:00:25|  2017-10-01 00:11:24|              1|         1.97|         1|                 N|         100|         229|           1|        9.5|  0.5|    0.5|         1|           0|                  0.3|        11.8|
# |       2| 2017-10-01 00:15:30|  2017-10-01 00:25:11|              1|         2.17|         1|                 N|         141|         142|           1|          9|  0.5|    0.5|      2.06|           0|                  0.3|       12.36|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+
# only showing top 5 rows
# Loaded full dataset with 300,700,143 rows

# %% [markdown]
# # Step B: Load Taxi Zone Reference Data for Joins

# %%
zone_path = "dbfs:/databricks-datasets/nyctaxi/taxizone"
zone_df = (spark.read
                .option("header", "true")
                .option("inferSchema", "true")
                .csv(zone_path))

zone_df = (zone_df
           .select("LocationID", "Borough", "Zone")
           .withColumnRenamed("LocationID", "LocationID_key")
           .withColumnRenamed("Borough", "Borough_name")
           .withColumnRenamed("Zone", "Zone_name"))

zone_df.show(5)
# Out:
# +--------------+-------------+--------------------+
# |LocationID_key| Borough_name|           Zone_name|
# +--------------+-------------+--------------------+
# |             1|          EWR|      Newark Airport|
# |             2|       Queens|         Jamaica Bay|
# |             3|        Bronx|Allerton/Pelham G...|
# |             4|    Manhattan|       Alphabet City|
# |             5|Staten Island|       Arden Heights|
# +--------------+-------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# # Step C: Column Transformations and Data Filtering

# %%
from pyspark.sql import functions as F

cols_needed = [
    "tpep_pickup_datetime","tpep_dropoff_datetime",
    "passenger_count","trip_distance",
    "PULocationID","DOLocationID",
    "fare_amount","tip_amount","total_amount","payment_type","RatecodeID"
]
df1 = df_dev.select([c for c in cols_needed if c in df_dev.columns])

num_cols_double = ["trip_distance","fare_amount","tip_amount","total_amount"]
num_cols_int    = ["passenger_count","PULocationID","DOLocationID","RatecodeID"]

df_cast = df1
for c in num_cols_double:
    if c in df_cast.columns:
        df_cast = df_cast.withColumn(c, F.col(c).cast("double"))
for c in num_cols_int:
    if c in df_cast.columns:
        df_cast = df_cast.withColumn(c, F.col(c).cast("int"))

df_cast = (df_cast
    .withColumn("tpep_pickup_datetime",  F.to_timestamp("tpep_pickup_datetime"))
    .withColumn("tpep_dropoff_datetime", F.to_timestamp("tpep_dropoff_datetime"))
)

df2 = (df_cast
    .withColumn(
        "trip_minutes",
        (F.col("tpep_dropoff_datetime").cast("long") - F.col("tpep_pickup_datetime").cast("long"))/60.0
    )
    .withColumn("pickup_hour", F.hour("tpep_pickup_datetime"))
    .withColumn("pickup_dow",  F.date_format("tpep_pickup_datetime","E"))
    .withColumn(
        "tip_rate",
        F.when(F.col("fare_amount") > 0,
               F.col("tip_amount") / F.col("fare_amount"))
         .otherwise(F.lit(None).cast("double"))
    )
)

df_clean = (df2
    .filter((F.col("trip_minutes") >= 1) & (F.col("trip_minutes") <= 180))
    .filter((F.col("trip_distance") >= 0.2) & (F.col("trip_distance") <= 50))
    .filter((F.col("passenger_count") >= 1) & (F.col("passenger_count") <= 6))
    .filter(F.col("total_amount") > 0)
)

df_clean.select("tpep_pickup_datetime","trip_minutes","trip_distance","passenger_count",
                "fare_amount","tip_amount","tip_rate").show(5)
# Out:
# +--------------------+------------------+-------------+---------------+-----------+----------+-------------------+
# |tpep_pickup_datetime|      trip_minutes|trip_distance|passenger_count|fare_amount|tip_amount|           tip_rate|
# +--------------------+------------------+-------------+---------------+-----------+----------+-------------------+
# | 2017-10-01 00:01:50|12.383333333333333|          2.0|              1|       10.0|       0.0|                0.0|
# | 2017-10-01 00:02:43| 5.866666666666666|          2.3|              2|        8.0|      1.85|            0.23125|
# | 2017-10-01 00:12:08|13.683333333333334|          2.8|              3|       13.0|      1.72| 0.1323076923076923|
# | 2017-10-01 00:00:25|10.983333333333333|         1.97|              1|        9.5|       1.0|0.10526315789473684|
# | 2017-10-01 00:15:30| 9.683333333333334|         2.17|              1|        9.0|      2.06| 0.2288888888888889|
# +--------------------+------------------+-------------+---------------+-----------+----------+-------------------+
# only showing top 5 rows

# %% [markdown]
# # Step D: Join Taxi Trips with Zone Information (PU and DO)

# %%
df_pu = (df_clean
         .join(zone_df.withColumnRenamed("LocationID_key","PULocationID"),
               on="PULocationID", how="left")
         .withColumnRenamed("Borough_name","PU_Borough")
         .withColumnRenamed("Zone_name","PU_Zone"))

df_joined = (df_pu
             .join(zone_df.withColumnRenamed("LocationID_key","DOLocationID"),
                   on="DOLocationID", how="left")
             .withColumnRenamed("Borough_name","DO_Borough")
             .withColumnRenamed("Zone_name","DO_Zone"))

df_joined.select("PULocationID","PU_Borough","PU_Zone",
                 "DOLocationID","DO_Borough","DO_Zone","trip_minutes","tip_rate").show(5)
# Out:
# +------------+----------+-------------------+------------+----------+--------------------+------------------+-------------------+
# |PULocationID|PU_Borough|            PU_Zone|DOLocationID|DO_Borough|             DO_Zone|      trip_minutes|           tip_rate|
# +------------+----------+-------------------+------------+----------+--------------------+------------------+-------------------+
# |         142| Manhattan|Lincoln Square East|         233| Manhattan| UN/Turtle Bay South|12.383333333333333|                0.0|
# |         142| Manhattan|Lincoln Square East|         166| Manhattan| Morningside Heights| 5.866666666666666|            0.23125|
# |         151| Manhattan|   Manhattan Valley|         262| Manhattan|      Yorkville East|13.683333333333334| 0.1323076923076923|
# |         100| Manhattan|   Garment District|         229| Manhattan|Sutton Place/Turt...|10.983333333333333|0.10526315789473684|
# |         141| Manhattan|    Lenox Hill West|         142| Manhattan| Lincoln Square East| 9.683333333333334| 0.2288888888888889|
# +------------+----------+-------------------+------------+----------+--------------------+------------------+-------------------+
# only showing top 5 rows

# %% [markdown]
# # Step E: GroupBy Aggregations

# %%
agg_df = (df_joined
          .groupBy("PU_Borough","pickup_hour")
          .agg(F.count("*").alias("trips"),
               F.avg("trip_distance").alias("avg_miles"),
               F.avg("total_amount").alias("avg_total"),
               F.avg("tip_rate").alias("avg_tip_rate"))
          .orderBy(F.desc("trips"))
         )

agg_df.show(20, truncate=False)
# Out:
# +----------+-----------+--------+------------------+------------------+-------------------+
# |PU_Borough|pickup_hour|trips   |avg_miles         |avg_total         |avg_tip_rate       |
# +----------+-----------+--------+------------------+------------------+-------------------+
# |Manhattan |18         |17482004|2.136958465974506 |15.192062065590234|0.16856183517145382|
# |Manhattan |19         |16903389|2.1567067219478986|14.799441652734169|0.16963685194799008|
# |Manhattan |17         |15394948|2.226213928751183 |15.833075497822092|0.16094658442483903|
# |Manhattan |20         |15339035|2.310482299571011 |14.582196747653878|0.17216770597667894|
# |Manhattan |21         |15143904|2.4475205647103944|14.911812764341487|0.1697537024051325 |
# |Manhattan |14         |14716392|2.455025166494635 |15.919868422170422|0.1470033868378145 |
# |Manhattan |15         |14592458|2.390400012115867 |15.798106106531106|0.1482791990605973 |
# |Manhattan |22         |14262112|2.5817350109156436|15.372424419274372|0.16945512197776516|
# |Manhattan |13         |14105841|2.393113524390386 |15.63961773276423 |0.14840857684412537|
# |Manhattan |12         |14067046|2.2968598133538634|15.259208877200146|0.14819354306752563|
# |Manhattan |16         |13392841|2.343861166574005 |16.244666659539327|0.1575684333115927 |
# |Manhattan |11         |13287264|2.2491193740110824|14.9982659281306  |0.14831096626764062|
# |Manhattan |9          |12690558|2.1985585038892714|14.710579182522332|0.15977755658346832|
# |Manhattan |10         |12618708|2.2014523800693446|14.698350222492813|0.15436900795521286|
# |Manhattan |8          |12467132|2.2616221990751484|14.679984787153643|0.16681752654969417|
# |Manhattan |23         |11466089|2.6947844134124677|15.462447335745004|0.16720386477052238|
# |Manhattan |7          |10022217|2.457270234719534 |14.369846824277325|0.16669094426089348|
# |Manhattan |0          |8397248 |2.8028791349261195|15.42318164590959 |0.16882846734370924|
# |Manhattan |1          |6056260 |2.874059470696444 |15.377091123888878|0.17035055574666388|
# |Manhattan |6          |5871225 |2.990742012101401 |15.428321493383057|0.15277750067819262|
# +----------+-----------+--------+------------------+------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# # Step F: SQL Queries on Cleaned Dataset

# %%
df_joined.createOrReplaceTempView("nyc_taxi_clean")

# SQL Query 1
sql_1 = spark.sql("""
SELECT payment_type,
       COUNT(*)        AS trips,
       AVG(tip_rate)   AS avg_tip_rate,
       AVG(total_amount) AS avg_total
FROM nyc_taxi_clean
GROUP BY payment_type
ORDER BY trips DESC
""")
sql_1.show(10, truncate=False)

# SQL Query 2
sql_2 = spark.sql("""
SELECT PU_Borough,
       pickup_dow,
       COUNT(*) AS trips
FROM nyc_taxi_clean
GROUP BY PU_Borough, pickup_dow
ORDER BY PU_Borough, trips DESC
""")
sql_2.show(20, truncate=False)
# Out:
# +------------+---------+---------------------+------------------+
# |payment_type|trips    |avg_tip_rate         |avg_total         |
# +------------+---------+---------------------+------------------+
# |1           |208059451|0.23123426126361196  |18.585367609842752|
# |2           |88894373 |8.12385093996425E-6  |14.220029456288684|
# |3           |1059158  |2.7777545480639173E-4|23.153573432861332|
# |4           |336246   |3.359316588845696E-4 |21.558201465592308|
# |5           |4        |0.05                 |16.599999999999998|
# +------------+---------+---------------------+------------------+
#
# +----------+----------+------+
# |PU_Borough|pickup_dow|trips |
# +----------+----------+------+
# |Bronx     |Sun       |49246 |
# |Bronx     |Fri       |48507 |
# |Bronx     |Sat       |47886 |
# |Bronx     |Thu       |41624 |
# |Bronx     |Wed       |41344 |
# |Bronx     |Tue       |40982 |
# |Bronx     |Mon       |39354 |
# |Brooklyn  |Sat       |682931|
# |Brooklyn  |Sun       |627858|
# |Brooklyn  |Fri       |564034|
# |Brooklyn  |Thu       |506512|
# |Brooklyn  |Wed       |468398|
# |Brooklyn  |Tue       |429662|
# |Brooklyn  |Mon       |400821|
# |Cash      |Wed       |66    |
# |Cash      |Sat       |43    |
# |Cash      |Sun       |41    |
# |Cash      |Fri       |39    |
# |Cash      |Mon       |37    |
# |Cash      |Thu       |33    |
# +----------+----------+------+
# only showing top 20 rows

# %% [markdown]
# # Step G: Performance Analysis – Explain Plan

# %%
df_joined.explain(True)
agg_df.explain(True)
# Out:
# == Parsed Logical Plan ==
# Project [DOLocationID#13217, PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, PU_Zone#13333, DO_Borough#13341, Zone_name#13170 AS DO_Zone#13342]
# +- Project [DOLocationID#13217, PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, PU_Zone#13333, Borough_name#13169 AS DO_Borough#13341, Zone_name#13170]
#    +- Project [DOLocationID#13217, PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, PU_Zone#13333, Borough_name#13169, Zone_name#13170]
#       +- Join LeftOuter, (cast(DOLocationID#13217 as bigint) = cast(DOLocationID#13335 as bigint))
#          :- Project [PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, Zone_name#13170 AS PU_Zone#13333]
#          :  +- Project [PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, Borough_name#13169 AS PU_Borough#13332, Zone_name#13170]
#          :     +- Project [PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, Borough_name#13169, Zone_name#13170]
#          :        +- Join LeftOuter, (cast(PULocationID#13214 as bigint) = cast(PULocationID#13331 as bigint))
#          :           :- Filter (total_amount#13208 > cast(0 as double))
#          :           :  +- Filter ((passenger_count#13211 >= 1) AND (passenger_count#13211 <= 6))
#          :           :     +- Filter ((trip_distance#13199 >= 0.2) AND (trip_distance#13199 <= cast(50 as double)))
#          :           :        +- Filter ((trip_minutes#13272 >= cast(1 as double)) AND (trip_minutes#13272 <= cast(180 as double)))
#          :           :           +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, CASE WHEN (fare_amount#13202 > cast(0 as double)) THEN (tip_amount#13205 / fare_amount#13202) ELSE cast(null as double) END AS tip_rate#13278]
#          :           :              +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, date_format(tpep_pickup_datetime#13267, E, Some(Etc/UTC)) AS pickup_dow#13276]
#          :           :                 +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, hour(tpep_pickup_datetime#13267, Some(Etc/UTC)) AS pickup_hour#13274]
#          :           :                    +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, (cast((cast(tpep_dropoff_datetime#13269 as bigint) - cast(tpep_pickup_datetime#13267 as bigint)) as double) / cast(60.0 as double)) AS trip_minutes#13272]
#          :           :                       +- Project [tpep_pickup_datetime#13267, to_timestamp(tpep_dropoff_datetime#13035, None, TimestampType, Some(Etc/UTC), true) AS tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265]
#          :           :                          +- Project [to_timestamp(tpep_pickup_datetime#13034, None, TimestampType, Some(Etc/UTC), true) AS tpep_pickup_datetime#13267, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265]
#          :           :                             +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, cast(RatecodeID#13038 as int) AS RatecodeID#13265]
#          :           :                                +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, PULocationID#13214, cast(DOLocationID#13041 as int) AS DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13038]
#          :           :                                   +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, cast(PULocationID#13040 as int) AS PULocationID#13214, DOLocationID#13041, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13038]
#          :           :                                      +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, cast(passenger_count#13036 as int) AS passenger_count#13211, trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13038]
#          :           :                                         +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13202, tip_amount#13205, cast(total_amount#13049 as double) AS total_amount#13208, payment_type#13042, RatecodeID#13038]
#          :           :                                            +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13202, cast(tip_amount#13046 as double) AS tip_amount#13205, total_amount#13049, payment_type#13042, RatecodeID#13038]
#          :           :                                               +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13199, PULocationID#13040, DOLocationID#13041, cast(fare_amount#13043 as double) AS fare_amount#13202, tip_amount#13046, total_amount#13049, payment_type#13042, RatecodeID#13038]
#          :           :                                                  +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, cast(trip_distance#13037 as double) AS trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13043, tip_amount#13046, total_amount#13049, payment_type#13042, RatecodeID#13038]
#          :           :                                                     +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13037, PULocationID#13040, DOLocationID#13041, fare_amount#13043, tip_amount#13046, total_amount#13049, payment_type#13042, RatecodeID#13038]
#          :           :                                                        +- Relation [VendorID#13033,tpep_pickup_datetime#13034,tpep_dropoff_datetime#13035,passenger_count#13036,trip_distance#13037,RatecodeID#13038,store_and_fwd_flag#13039,PULocationID#13040,DOLocationID#13041,payment_type#13042,fare_amount#13043,extra#13044,mta_tax#13045,tip_amount#13046,tolls_amount#13047,improvement_surcharge#13048,total_amount#13049] csv
#          :           +- Project [LocationID_key#13168 AS PULocationID#13331, Borough_name#13169, Zone_name#13170]
#          :              +- Project [LocationID_key#13168, Borough_name#13169, Zone#13147 AS Zone_name#13170]
#          :                 +- Project [LocationID_key#13168, Borough#13146 AS Borough_name#13169, Zone#13147]
#          :                    +- Project [LocationID#13145 AS LocationID_key#13168, Borough#13146, Zone#13147]
#          :                       +- Project [LocationID#13145, Borough#13146, Zone#13147]
#          :                          +- Relation [LocationID#13145,Borough#13146,Zone#13147,service_zone#13148] csv
#          +- Project [LocationID_key#13168 AS DOLocationID#13335, Borough_name#13169, Zone_name#13170]
#             +- Project [LocationID_key#13168, Borough_name#13169, Zone#13338 AS Zone_name#13170]
#                +- Project [LocationID_key#13168, Borough#13337 AS Borough_name#13169, Zone#13338]
#                   +- Project [LocationID#13336 AS LocationID_key#13168, Borough#13337, Zone#13338]
#                      +- Project [LocationID#13336, Borough#13337, Zone#13338]
#                         +- Relation [LocationID#13336,Borough#13337,Zone#13338,service_zone#13339] csv
#
# == Analyzed Logical Plan ==
# DOLocationID: int, PULocationID: int, tpep_pickup_datetime: timestamp, tpep_dropoff_datetime: timestamp, passenger_count: int, trip_distance: double, fare_amount: double, tip_amount: double, total_amount: double, payment_type: string, RatecodeID: int, trip_minutes: double, pickup_hour: int, pickup_dow: string, tip_rate: double, PU_Borough: string, PU_Zone: string, DO_Borough: string, DO_Zone: string
# Project [DOLocationID#13217, PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, PU_Zone#13333, DO_Borough#13341, Zone_name#13170 AS DO_Zone#13342]
# +- Project [DOLocationID#13217, PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, PU_Zone#13333, Borough_name#13169 AS DO_Borough#13341, Zone_name#13170]
#    +- Project [DOLocationID#13217, PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, PU_Zone#13333, Borough_name#13169, Zone_name#13170]
#       +- Join LeftOuter, (cast(DOLocationID#13217 as bigint) = cast(DOLocationID#13335 as bigint))
#          :- Project [PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, Zone_name#13170 AS PU_Zone#13333]
#          :  +- Project [PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, Borough_name#13169 AS PU_Borough#13332, Zone_name#13170]
#          :     +- Project [PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, Borough_name#13169, Zone_name#13170]
#          :        +- Join LeftOuter, (cast(PULocationID#13214 as bigint) = cast(PULocationID#13331 as bigint))
#          :           :- Filter (total_amount#13208 > cast(0 as double))
#          :           :  +- Filter ((passenger_count#13211 >= 1) AND (passenger_count#13211 <= 6))
#          :           :     +- Filter ((trip_distance#13199 >= 0.2) AND (trip_distance#13199 <= cast(50 as double)))
#          :           :        +- Filter ((trip_minutes#13272 >= cast(1 as double)) AND (trip_minutes#13272 <= cast(180 as double)))
#          :           :           +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, CASE WHEN (fare_amount#13202 > cast(0 as double)) THEN (tip_amount#13205 / fare_amount#13202) ELSE cast(null as double) END AS tip_rate#13278]
#          :           :              +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, date_format(tpep_pickup_datetime#13267, E, Some(Etc/UTC)) AS pickup_dow#13276]
#          :           :                 +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, hour(tpep_pickup_datetime#13267, Some(Etc/UTC)) AS pickup_hour#13274]
#          :           :                    +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, (cast((cast(tpep_dropoff_datetime#13269 as bigint) - cast(tpep_pickup_datetime#13267 as bigint)) as double) / cast(60.0 as double)) AS trip_minutes#13272]
#          :           :                       +- Project [tpep_pickup_datetime#13267, to_timestamp(tpep_dropoff_datetime#13035, None, TimestampType, Some(Etc/UTC), true) AS tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265]
#          :           :                          +- Project [to_timestamp(tpep_pickup_datetime#13034, None, TimestampType, Some(Etc/UTC), true) AS tpep_pickup_datetime#13267, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265]
#          :           :                             +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, cast(RatecodeID#13038 as int) AS RatecodeID#13265]
#          :           :                                +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, PULocationID#13214, cast(DOLocationID#13041 as int) AS DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13038]
#          :           :                                   +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, cast(PULocationID#13040 as int) AS PULocationID#13214, DOLocationID#13041, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13038]
#          :           :                                      +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, cast(passenger_count#13036 as int) AS passenger_count#13211, trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13038]
#          :           :                                         +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13202, tip_amount#13205, cast(total_amount#13049 as double) AS total_amount#13208, payment_type#13042, RatecodeID#13038]
#          :           :                                            +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13202, cast(tip_amount#13046 as double) AS tip_amount#13205, total_amount#13049, payment_type#13042, RatecodeID#13038]
#          :           :                                               +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13199, PULocationID#13040, DOLocationID#13041, cast(fare_amount#13043 as double) AS fare_amount#13202, tip_amount#13046, total_amount#13049, payment_type#13042, RatecodeID#13038]
#          :           :                                                  +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, cast(trip_distance#13037 as double) AS trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13043, tip_amount#13046, total_amount#13049, payment_type#13042, RatecodeID#13038]
#          :           :                                                     +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13037, PULocationID#13040, DOLocationID#13041, fare_amount#13043, tip_amount#13046, total_amount#13049, payment_type#13042, RatecodeID#13038]
#          :           :                                                        +- Relation [VendorID#13033,tpep_pickup_datetime#13034,tpep_dropoff_datetime#13035,passenger_count#13036,trip_distance#13037,RatecodeID#13038,store_and_fwd_flag#13039,PULocationID#13040,DOLocationID#13041,payment_type#13042,fare_amount#13043,extra#13044,mta_tax#13045,tip_amount#13046,tolls_amount#13047,improvement_surcharge#13048,total_amount#13049] csv
#          :           +- Project [LocationID_key#13168 AS PULocationID#13331, Borough_name#13169, Zone_name#13170]
#          :              +- Project [LocationID_key#13168, Borough_name#13169, Zone#13147 AS Zone_name#13170]
#          :                 +- Project [LocationID_key#13168, Borough#13146 AS Borough_name#13169, Zone#13147]
#          :                    +- Project [LocationID#13145 AS LocationID_key#13168, Borough#13146, Zone#13147]
#          :                       +- Project [LocationID#13145, Borough#13146, Zone#13147]
#          :                          +- Relation [LocationID#13145,Borough#13146,Zone#13147,service_zone#13148] csv
#          +- Project [LocationID_key#13168 AS DOLocationID#13335, Borough_name#13169, Zone_name#13170]
#             +- Project [LocationID_key#13168, Borough_name#13169, Zone#13338 AS Zone_name#13170]
#                +- Project [LocationID_key#13168, Borough#13337 AS Borough_name#13169, Zone#13338]
#                   +- Project [LocationID#13336 AS LocationID_key#13168, Borough#13337, Zone#13338]
#                      +- Project [LocationID#13336, Borough#13337, Zone#13338]
#                         +- Relation [LocationID#13336,Borough#13337,Zone#13338,service_zone#13339] csv
#
# == Optimized Logical Plan ==
# Project [DOLocationID#13217, PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, PU_Zone#13333, Borough_name#13169 AS DO_Borough#13341, Zone_name#13170 AS DO_Zone#13342]
# +- Join LeftOuter, (cast(DOLocationID#13217 as bigint) = cast(DOLocationID#13335 as bigint))
#    :- Project [PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, Borough_name#13169 AS PU_Borough#13332, Zone_name#13170 AS PU_Zone#13333]
#    :  +- Join LeftOuter, (cast(PULocationID#13214 as bigint) = cast(PULocationID#13331 as bigint))
#    :     :- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, (cast((cast(tpep_dropoff_datetime#13269 as bigint) - cast(tpep_pickup_datetime#13267 as bigint)) as double) / 60.0) AS trip_minutes#13272, hour(tpep_pickup_datetime#13267, Some(Etc/UTC)) AS pickup_hour#13274, date_format(tpep_pickup_datetime#13267, E, Some(Etc/UTC)) AS pickup_dow#13276, CASE WHEN (fare_amount#13202 > 0.0) THEN (tip_amount#13205 / fare_amount#13202) END AS tip_rate#13278]
#    :     :  +- Project [cast(tpep_pickup_datetime#13034 as timestamp) AS tpep_pickup_datetime#13267, cast(tpep_dropoff_datetime#13035 as timestamp) AS tpep_dropoff_datetime#13269, cast(passenger_count#13036 as int) AS passenger_count#13211, cast(trip_distance#13037 as double) AS trip_distance#13199, cast(PULocationID#13040 as int) AS PULocationID#13214, cast(DOLocationID#13041 as int) AS DOLocationID#13217, cast(fare_amount#13043 as double) AS fare_amount#13202, cast(tip_amount#13046 as double) AS tip_amount#13205, cast(total_amount#13049 as double) AS total_amount#13208, payment_type#13042, cast(RatecodeID#13038 as int) AS RatecodeID#13265]
#    :     :     +- Filter (((((((((((isnotnull(tpep_dropoff_datetime#13035) AND isnotnull(tpep_pickup_datetime#13034)) AND isnotnull(trip_distance#13037)) AND isnotnull(passenger_count#13036)) AND isnotnull(total_amount#13049)) AND (cast(passenger_count#13036 as int) >= 1)) AND (cast(passenger_count#13036 as int) <= 6)) AND (cast(trip_distance#13037 as double) >= 0.2)) AND (cast(trip_distance#13037 as double) <= 50.0)) AND (cast(total_amount#13049 as double) > 0.0)) AND ((cast((cast(cast(tpep_dropoff_datetime#13035 as timestamp) as bigint) - cast(cast(tpep_pickup_datetime#13034 as timestamp) as bigint)) as double) / 60.0) >= 1.0)) AND ((cast((cast(cast(tpep_dropoff_datetime#13035 as timestamp) as bigint) - cast(cast(tpep_pickup_datetime#13034 as timestamp) as bigint)) as double) / 60.0) <= 180.0))
#    :     :        +- Relation [VendorID#13033,tpep_pickup_datetime#13034,tpep_dropoff_datetime#13035,passenger_count#13036,trip_distance#13037,RatecodeID#13038,store_and_fwd_flag#13039,PULocationID#13040,DOLocationID#13041,payment_type#13042,fare_amount#13043,extra#13044,mta_tax#13045,tip_amount#13046,tolls_amount#13047,improvement_surcharge#13048,total_amount#13049] csv
#    :     +- Project [LocationID#13145 AS PULocationID#13331, Borough#13146 AS Borough_name#13169, Zone#13147 AS Zone_name#13170]
#    :        +- Filter isnotnull(LocationID#13145)
#    :           +- Relation [LocationID#13145,Borough#13146,Zone#13147,service_zone#13148] csv
#    +- Project [LocationID#13336 AS DOLocationID#13335, Borough#13337 AS Borough_name#13169, Zone#13338 AS Zone_name#13170]
#       +- Filter isnotnull(LocationID#13336)
#          +- Relation [LocationID#13336,Borough#13337,Zone#13338,service_zone#13339] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonProject [DOLocationID#13217, PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, PU_Zone#13333, Borough_name#13169 AS DO_Borough#13341, Zone_name#13170 AS DO_Zone#13342]
#          +- PhotonBroadcastHashJoin [cast(DOLocationID#13217 as bigint)], [cast(DOLocationID#13335 as bigint)], LeftOuter, BuildRight, false, true
#             :- PhotonProject [PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, Borough_name#13169 AS PU_Borough#13332, Zone_name#13170 AS PU_Zone#13333]
#             :  +- PhotonBroadcastHashJoin [cast(PULocationID#13214 as bigint)], [cast(PULocationID#13331 as bigint)], LeftOuter, BuildRight, false, true
#             :     :- PhotonProject [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, (cast((cast(tpep_dropoff_datetime#13269 as bigint) - cast(tpep_pickup_datetime#13267 as bigint)) as double) / 60.0) AS trip_minutes#13272, hour(tpep_pickup_datetime#13267, Some(Etc/UTC)) AS pickup_hour#13274, date_format(tpep_pickup_datetime#13267, E, Some(Etc/UTC)) AS pickup_dow#13276, CASE WHEN (fare_amount#13202 > 0.0) THEN (tip_amount#13205 / fare_amount#13202) END AS tip_rate#13278]
#             :     :  +- PhotonProject [cast(tpep_pickup_datetime#13034 as timestamp) AS tpep_pickup_datetime#13267, cast(tpep_dropoff_datetime#13035 as timestamp) AS tpep_dropoff_datetime#13269, cast(passenger_count#13036 as int) AS passenger_count#13211, cast(trip_distance#13037 as double) AS trip_distance#13199, cast(PULocationID#13040 as int) AS PULocationID#13214, cast(DOLocationID#13041 as int) AS DOLocationID#13217, cast(fare_amount#13043 as double) AS fare_amount#13202, cast(tip_amount#13046 as double) AS tip_amount#13205, cast(total_amount#13049 as double) AS total_amount#13208, payment_type#13042, cast(RatecodeID#13038 as int) AS RatecodeID#13265]
#             :     :     +- PhotonFilter (((((((((((isnotnull(tpep_dropoff_datetime#13035) AND isnotnull(tpep_pickup_datetime#13034)) AND isnotnull(trip_distance#13037)) AND isnotnull(passenger_count#13036)) AND isnotnull(total_amount#13049)) AND (cast(passenger_count#13036 as int) >= 1)) AND (cast(passenger_count#13036 as int) <= 6)) AND (cast(trip_distance#13037 as double) >= 0.2)) AND (cast(trip_distance#13037 as double) <= 50.0)) AND (cast(total_amount#13049 as double) > 0.0)) AND ((cast((cast(cast(tpep_dropoff_datetime#13035 as timestamp) as bigint) - cast(cast(tpep_pickup_datetime#13034 as timestamp) as bigint)) as double) / 60.0) >= 1.0)) AND ((cast((cast(cast(tpep_dropoff_datetime#13035 as timestamp) as bigint) - cast(cast(tpep_pickup_datetime#13034 as timestamp) as bigint)) as double) / 60.0) <= 180.0))
#             :     :        +- PhotonRowToColumnar
#             :     :           +- FileScan csv [tpep_pickup_datetime#13034,tpep_dropoff_datetime#13035,passenger_count#13036,trip_distance#13037,RatecodeID#13038,PULocationID#13040,DOLocationID#13041,payment_type#13042,fare_amount#13043,tip_amount#13046,total_amount#13049] Batched: false, DataFilters: [isnotnull(tpep_dropoff_datetime#13035), isnotnull(tpep_pickup_datetime#13034), isnotnull(trip_di..., Format: CSV, Location: InMemoryFileIndex(36 paths)[dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_201..., PartitionFilters: [], PushedFilters: [IsNotNull(tpep_dropoff_datetime), IsNotNull(tpep_pickup_datetime), IsNotNull(trip_distance), IsN..., ReadSchema: struct<tpep_pickup_datetime:string,tpep_dropoff_datetime:string,passenger_count:string,trip_dista...
#             :     +- PhotonShuffleExchangeSource
#             :        +- PhotonShuffleMapStage EXECUTOR_BROADCAST, [id=#17336]
#             :           +- PhotonShuffleExchangeSink SinglePartition
#             :              +- PhotonProject [LocationID#13145 AS PULocationID#13331, Borough#13146 AS Borough_name#13169, Zone#13147 AS Zone_name#13170]
#             :                 +- PhotonFilter isnotnull(LocationID#13145)
#             :                    +- PhotonRowToColumnar
#             :                       +- FileScan csv [LocationID#13145,Borough#13146,Zone#13147] Batched: false, DataFilters: [isnotnull(LocationID#13145)], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/databricks-datasets/nyctaxi/taxizone], PartitionFilters: [], PushedFilters: [IsNotNull(LocationID)], ReadSchema: struct<LocationID:string,Borough:string,Zone:string>
#             +- PhotonShuffleExchangeSource
#                +- PhotonShuffleMapStage EXECUTOR_BROADCAST, [id=#17349]
#                   +- PhotonShuffleExchangeSink SinglePartition
#                      +- PhotonProject [LocationID#13336 AS DOLocationID#13335, Borough#13337 AS Borough_name#13169, Zone#13338 AS Zone_name#13170]
#                         +- PhotonFilter isnotnull(LocationID#13336)
#                            +- PhotonRowToColumnar
#                               +- FileScan csv [LocationID#13336,Borough#13337,Zone#13338] Batched: false, DataFilters: [isnotnull(LocationID#13336)], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/databricks-datasets/nyctaxi/taxizone], PartitionFilters: [], PushedFilters: [IsNotNull(LocationID)], ReadSchema: struct<LocationID:string,Borough:string,Zone:string>
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Parsed Logical Plan ==
# 'Sort ['trips DESC NULLS LAST], true
# +- 'Aggregate ['PU_Borough, 'pickup_hour], ['PU_Borough, 'pickup_hour, 'count(*) AS trips#13581, 'avg('trip_distance) AS avg_miles#13582, 'avg('total_amount) AS avg_total#13583, 'avg('tip_rate) AS avg_tip_rate#13584]
#    +- Project [DOLocationID#13217, PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, PU_Zone#13333, DO_Borough#13341, Zone_name#13170 AS DO_Zone#13342]
#       +- Project [DOLocationID#13217, PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, PU_Zone#13333, Borough_name#13169 AS DO_Borough#13341, Zone_name#13170]
#          +- Project [DOLocationID#13217, PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, PU_Zone#13333, Borough_name#13169, Zone_name#13170]
#             +- Join LeftOuter, (cast(DOLocationID#13217 as bigint) = cast(DOLocationID#13335 as bigint))
#                :- Project [PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, Zone_name#13170 AS PU_Zone#13333]
#                :  +- Project [PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, Borough_name#13169 AS PU_Borough#13332, Zone_name#13170]
#                :     +- Project [PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, Borough_name#13169, Zone_name#13170]
#                :        +- Join LeftOuter, (cast(PULocationID#13214 as bigint) = cast(PULocationID#13331 as bigint))
#                :           :- Filter (total_amount#13208 > cast(0 as double))
#                :           :  +- Filter ((passenger_count#13211 >= 1) AND (passenger_count#13211 <= 6))
#                :           :     +- Filter ((trip_distance#13199 >= 0.2) AND (trip_distance#13199 <= cast(50 as double)))
#                :           :        +- Filter ((trip_minutes#13272 >= cast(1 as double)) AND (trip_minutes#13272 <= cast(180 as double)))
#                :           :           +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, CASE WHEN (fare_amount#13202 > cast(0 as double)) THEN (tip_amount#13205 / fare_amount#13202) ELSE cast(null as double) END AS tip_rate#13278]
#                :           :              +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, date_format(tpep_pickup_datetime#13267, E, Some(Etc/UTC)) AS pickup_dow#13276]
#                :           :                 +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, hour(tpep_pickup_datetime#13267, Some(Etc/UTC)) AS pickup_hour#13274]
#                :           :                    +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, (cast((cast(tpep_dropoff_datetime#13269 as bigint) - cast(tpep_pickup_datetime#13267 as bigint)) as double) / cast(60.0 as double)) AS trip_minutes#13272]
#                :           :                       +- Project [tpep_pickup_datetime#13267, to_timestamp(tpep_dropoff_datetime#13035, None, TimestampType, Some(Etc/UTC), true) AS tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265]
#                :           :                          +- Project [to_timestamp(tpep_pickup_datetime#13034, None, TimestampType, Some(Etc/UTC), true) AS tpep_pickup_datetime#13267, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265]
#                :           :                             +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, cast(RatecodeID#13038 as int) AS RatecodeID#13265]
#                :           :                                +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, PULocationID#13214, cast(DOLocationID#13041 as int) AS DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13038]
#                :           :                                   +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, cast(PULocationID#13040 as int) AS PULocationID#13214, DOLocationID#13041, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13038]
#                :           :                                      +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, cast(passenger_count#13036 as int) AS passenger_count#13211, trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13038]
#                :           :                                         +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13202, tip_amount#13205, cast(total_amount#13049 as double) AS total_amount#13208, payment_type#13042, RatecodeID#13038]
#                :           :                                            +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13202, cast(tip_amount#13046 as double) AS tip_amount#13205, total_amount#13049, payment_type#13042, RatecodeID#13038]
#                :           :                                               +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13199, PULocationID#13040, DOLocationID#13041, cast(fare_amount#13043 as double) AS fare_amount#13202, tip_amount#13046, total_amount#13049, payment_type#13042, RatecodeID#13038]
#                :           :                                                  +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, cast(trip_distance#13037 as double) AS trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13043, tip_amount#13046, total_amount#13049, payment_type#13042, RatecodeID#13038]
#                :           :                                                     +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13037, PULocationID#13040, DOLocationID#13041, fare_amount#13043, tip_amount#13046, total_amount#13049, payment_type#13042, RatecodeID#13038]
#                :           :                                                        +- Relation [VendorID#13033,tpep_pickup_datetime#13034,tpep_dropoff_datetime#13035,passenger_count#13036,trip_distance#13037,RatecodeID#13038,store_and_fwd_flag#13039,PULocationID#13040,DOLocationID#13041,payment_type#13042,fare_amount#13043,extra#13044,mta_tax#13045,tip_amount#13046,tolls_amount#13047,improvement_surcharge#13048,total_amount#13049] csv
#                :           +- Project [LocationID_key#13168 AS PULocationID#13331, Borough_name#13169, Zone_name#13170]
#                :              +- Project [LocationID_key#13168, Borough_name#13169, Zone#13147 AS Zone_name#13170]
#                :                 +- Project [LocationID_key#13168, Borough#13146 AS Borough_name#13169, Zone#13147]
#                :                    +- Project [LocationID#13145 AS LocationID_key#13168, Borough#13146, Zone#13147]
#                :                       +- Project [LocationID#13145, Borough#13146, Zone#13147]
#                :                          +- Relation [LocationID#13145,Borough#13146,Zone#13147,service_zone#13148] csv
#                +- Project [LocationID_key#13168 AS DOLocationID#13335, Borough_name#13169, Zone_name#13170]
#                   +- Project [LocationID_key#13168, Borough_name#13169, Zone#13338 AS Zone_name#13170]
#                      +- Project [LocationID_key#13168, Borough#13337 AS Borough_name#13169, Zone#13338]
#                         +- Project [LocationID#13336 AS LocationID_key#13168, Borough#13337, Zone#13338]
#                            +- Project [LocationID#13336, Borough#13337, Zone#13338]
#                               +- Relation [LocationID#13336,Borough#13337,Zone#13338,service_zone#13339] csv
#
# == Analyzed Logical Plan ==
# PU_Borough: string, pickup_hour: int, trips: bigint, avg_miles: double, avg_total: double, avg_tip_rate: double
# Sort [trips#13581L DESC NULLS LAST], true
# +- Aggregate [PU_Borough#13332, pickup_hour#13274], [PU_Borough#13332, pickup_hour#13274, count(1) AS trips#13581L, avg(trip_distance#13199) AS avg_miles#13582, avg(total_amount#13208) AS avg_total#13583, avg(tip_rate#13278) AS avg_tip_rate#13584]
#    +- Project [DOLocationID#13217, PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, PU_Zone#13333, DO_Borough#13341, Zone_name#13170 AS DO_Zone#13342]
#       +- Project [DOLocationID#13217, PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, PU_Zone#13333, Borough_name#13169 AS DO_Borough#13341, Zone_name#13170]
#          +- Project [DOLocationID#13217, PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, PU_Zone#13333, Borough_name#13169, Zone_name#13170]
#             +- Join LeftOuter, (cast(DOLocationID#13217 as bigint) = cast(DOLocationID#13335 as bigint))
#                :- Project [PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, PU_Borough#13332, Zone_name#13170 AS PU_Zone#13333]
#                :  +- Project [PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, Borough_name#13169 AS PU_Borough#13332, Zone_name#13170]
#                :     +- Project [PULocationID#13214, tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, tip_rate#13278, Borough_name#13169, Zone_name#13170]
#                :        +- Join LeftOuter, (cast(PULocationID#13214 as bigint) = cast(PULocationID#13331 as bigint))
#                :           :- Filter (total_amount#13208 > cast(0 as double))
#                :           :  +- Filter ((passenger_count#13211 >= 1) AND (passenger_count#13211 <= 6))
#                :           :     +- Filter ((trip_distance#13199 >= 0.2) AND (trip_distance#13199 <= cast(50 as double)))
#                :           :        +- Filter ((trip_minutes#13272 >= cast(1 as double)) AND (trip_minutes#13272 <= cast(180 as double)))
#                :           :           +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, pickup_dow#13276, CASE WHEN (fare_amount#13202 > cast(0 as double)) THEN (tip_amount#13205 / fare_amount#13202) ELSE cast(null as double) END AS tip_rate#13278]
#                :           :              +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, pickup_hour#13274, date_format(tpep_pickup_datetime#13267, E, Some(Etc/UTC)) AS pickup_dow#13276]
#                :           :                 +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, trip_minutes#13272, hour(tpep_pickup_datetime#13267, Some(Etc/UTC)) AS pickup_hour#13274]
#                :           :                    +- Project [tpep_pickup_datetime#13267, tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265, (cast((cast(tpep_dropoff_datetime#13269 as bigint) - cast(tpep_pickup_datetime#13267 as bigint)) as double) / cast(60.0 as double)) AS trip_minutes#13272]
#                :           :                       +- Project [tpep_pickup_datetime#13267, to_timestamp(tpep_dropoff_datetime#13035, None, TimestampType, Some(Etc/UTC), true) AS tpep_dropoff_datetime#13269, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265]
#                :           :                          +- Project [to_timestamp(tpep_pickup_datetime#13034, None, TimestampType, Some(Etc/UTC), true) AS tpep_pickup_datetime#13267, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13265]
#                :           :                             +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, PULocationID#13214, DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, cast(RatecodeID#13038 as int) AS RatecodeID#13265]
#                :           :                                +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, PULocationID#13214, cast(DOLocationID#13041 as int) AS DOLocationID#13217, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13038]
#                :           :                                   +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13211, trip_distance#13199, cast(PULocationID#13040 as int) AS PULocationID#13214, DOLocationID#13041, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13038]
#                :           :                                      +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, cast(passenger_count#13036 as int) AS passenger_count#13211, trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13202, tip_amount#13205, total_amount#13208, payment_type#13042, RatecodeID#13038]
#                :           :                                         +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13202, tip_amount#13205, cast(total_amount#13049 as double) AS total_amount#13208, payment_type#13042, RatecodeID#13038]
#                :           :                                            +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13202, cast(tip_amount#13046 as double) AS tip_amount#13205, total_amount#13049, payment_type#13042, RatecodeID#13038]
#                :           :                                               +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13199, PULocationID#13040, DOLocationID#13041, cast(fare_amount#13043 as double) AS fare_amount#13202, tip_amount#13046, total_amount#13049, payment_type#13042, RatecodeID#13038]
#                :           :                                                  +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, cast(trip_distance#13037 as double) AS trip_distance#13199, PULocationID#13040, DOLocationID#13041, fare_amount#13043, tip_amount#13046, total_amount#13049, payment_type#13042, RatecodeID#13038]
#                :           :                                                     +- Project [tpep_pickup_datetime#13034, tpep_dropoff_datetime#13035, passenger_count#13036, trip_distance#13037, PULocationID#13040, DOLocationID#13041, fare_amount#13043, tip_amount#13046, total_amount#13049, payment_type#13042, RatecodeID#13038]
#                :           :                                                        +- Relation [VendorID#13033,tpep_pickup_datetime#13034,tpep_dropoff_datetime#13035,passenger_count#13036,trip_distance#13037,RatecodeID#13038,store_and_fwd_flag#13039,PULocationID#13040,DOLocationID#13041,payment_type#13042,fare_amount#13043,extra#13044,mta_tax#13045,tip_amount#13046,tolls_amount#13047,improvement_surcharge#13048,total_amount#13049] csv
#                :           +- Project [LocationID_key#13168 AS PULocationID#13331, Borough_name#13169, Zone_name#13170]
#                :              +- Project [LocationID_key#13168, Borough_name#13169, Zone#13147 AS Zone_name#13170]
#                :                 +- Project [LocationID_key#13168, Borough#13146 AS Borough_name#13169, Zone#13147]
#                :                    +- Project [LocationID#13145 AS LocationID_key#13168, Borough#13146, Zone#13147]
#                :                       +- Project [LocationID#13145, Borough#13146, Zone#13147]
#                :                          +- Relation [LocationID#13145,Borough#13146,Zone#13147,service_zone#13148] csv
#                +- Project [LocationID_key#13168 AS DOLocationID#13335, Borough_name#13169, Zone_name#13170]
#                   +- Project [LocationID_key#13168, Borough_name#13169, Zone#13338 AS Zone_name#13170]
#                      +- Project [LocationID_key#13168, Borough#13337 AS Borough_name#13169, Zone#13338]
#                         +- Project [LocationID#13336 AS LocationID_key#13168, Borough#13337, Zone#13338]
#                            +- Project [LocationID#13336, Borough#13337, Zone#13338]
#                               +- Relation [LocationID#13336,Borough#13337,Zone#13338,service_zone#13339] csv
#
# == Optimized Logical Plan ==
# Sort [trips#13581L DESC NULLS LAST], true
# +- Aggregate [PU_Borough#13332, pickup_hour#13274], [PU_Borough#13332, pickup_hour#13274, count(1) AS trips#13581L, avg(trip_distance#13199) AS avg_miles#13582, avg(total_amount#13208) AS avg_total#13583, avg(tip_rate#13278) AS avg_tip_rate#13584]
#    +- Project [trip_distance#13199, total_amount#13208, pickup_hour#13274, tip_rate#13278, PU_Borough#13332]
#       +- Join LeftOuter, (cast(DOLocationID#13217 as bigint) = cast(DOLocationID#13335 as bigint))
#          :- Project [trip_distance#13199, DOLocationID#13217, total_amount#13208, pickup_hour#13274, tip_rate#13278, Borough_name#13169 AS PU_Borough#13332]
#          :  +- Join LeftOuter, (cast(PULocationID#13214 as bigint) = cast(PULocationID#13331 as bigint))
#          :     :- Project [trip_distance#13199, PULocationID#13214, DOLocationID#13217, total_amount#13208, pickup_hour#13274, CASE WHEN (fare_amount#13202 > 0.0) THEN (tip_amount#13205 / fare_amount#13202) END AS tip_rate#13278]
#          :     :  +- Project [cast(trip_distance#13037 as double) AS trip_distance#13199, cast(PULocationID#13040 as int) AS PULocationID#13214, cast(DOLocationID#13041 as int) AS DOLocationID#13217, cast(fare_amount#13043 as double) AS fare_amount#13202, cast(tip_amount#13046 as double) AS tip_amount#13205, cast(total_amount#13049 as double) AS total_amount#13208, hour(cast(tpep_pickup_datetime#13034 as timestamp), Some(Etc/UTC)) AS pickup_hour#13274]
#          :     :     +- Filter (((((((((((isnotnull(tpep_dropoff_datetime#13035) AND isnotnull(tpep_pickup_datetime#13034)) AND isnotnull(trip_distance#13037)) AND isnotnull(passenger_count#13036)) AND isnotnull(total_amount#13049)) AND (cast(passenger_count#13036 as int) >= 1)) AND (cast(passenger_count#13036 as int) <= 6)) AND (cast(trip_distance#13037 as double) >= 0.2)) AND (cast(trip_distance#13037 as double) <= 50.0)) AND (cast(total_amount#13049 as double) > 0.0)) AND ((cast((cast(cast(tpep_dropoff_datetime#13035 as timestamp) as bigint) - cast(cast(tpep_pickup_datetime#13034 as timestamp) as bigint)) as double) / 60.0) >= 1.0)) AND ((cast((cast(cast(tpep_dropoff_datetime#13035 as timestamp) as bigint) - cast(cast(tpep_pickup_datetime#13034 as timestamp) as bigint)) as double) / 60.0) <= 180.0))
#          :     :        +- Relation [VendorID#13033,tpep_pickup_datetime#13034,tpep_dropoff_datetime#13035,passenger_count#13036,trip_distance#13037,RatecodeID#13038,store_and_fwd_flag#13039,PULocationID#13040,DOLocationID#13041,payment_type#13042,fare_amount#13043,extra#13044,mta_tax#13045,tip_amount#13046,tolls_amount#13047,improvement_surcharge#13048,total_amount#13049] csv
#          :     +- Project [LocationID#13145 AS PULocationID#13331, Borough#13146 AS Borough_name#13169]
#          :        +- Filter isnotnull(LocationID#13145)
#          :           +- Relation [LocationID#13145,Borough#13146,Zone#13147,service_zone#13148] csv
#          +- Project [LocationID#13336 AS DOLocationID#13335]
#             +- Filter isnotnull(LocationID#13336)
#                +- Relation [LocationID#13336,Borough#13337,Zone#13338,service_zone#13339] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonSort [trips#13581L DESC NULLS LAST]
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#17777]
#                +- PhotonShuffleExchangeSink rangepartitioning(trips#13581L DESC NULLS LAST, 1024)
#                   +- PhotonGroupingAgg(limit=None, keys=[PU_Borough#13332, pickup_hour#13274], functions=[finalmerge_count(merge count#13885L) AS count(1)#13880L, finalmerge_avg(merge sum#13888, count#13889L) AS avg(trip_distance)#13881, finalmerge_avg(merge sum#13892, count#13893L) AS avg(total_amount)#13882, finalmerge_avg(merge sum#13896, count#13897L) AS avg(tip_rate)#13883], output=[PU_Borough#13332, pickup_hour#13274, trips#13581L, avg_miles#13582, avg_total#13583, avg_tip_rate#13584])
#                      +- PhotonShuffleExchangeSource
#                         +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#17771]
#                            +- PhotonShuffleExchangeSink hashpartitioning(PU_Borough#13332, pickup_hour#13274, 1024)
#                               +- PhotonGroupingAgg(limit=None, keys=[PU_Borough#13332, pickup_hour#13274], functions=[partial_count(1) AS count#13885L, partial_avg(trip_distance#13199) AS (sum#13888, count#13889L), partial_avg(total_amount#13208) AS (sum#13892, count#13893L), partial_avg(tip_rate#13278) AS (sum#13896, count#13897L)], output=[PU_Borough#13332, pickup_hour#13274, count#13885L, sum#13888, count#13889L, sum#13892, count#13893L, sum#13896, count#13897L])
#                                  +- PhotonProject [trip_distance#13199, total_amount#13208, pickup_hour#13274, tip_rate#13278, PU_Borough#13332]
#                                     +- PhotonBroadcastHashJoin [cast(DOLocationID#13217 as bigint)], [cast(DOLocationID#13335 as bigint)], LeftOuter, BuildRight, false, true
#                                        :- PhotonProject [trip_distance#13199, DOLocationID#13217, total_amount#13208, pickup_hour#13274, tip_rate#13278, Borough_name#13169 AS PU_Borough#13332]
#                                        :  +- PhotonBroadcastHashJoin [cast(PULocationID#13214 as bigint)], [cast(PULocationID#13331 as bigint)], LeftOuter, BuildRight, false, true
#                                        :     :- PhotonProject [trip_distance#13199, PULocationID#13214, DOLocationID#13217, total_amount#13208, pickup_hour#13274, CASE WHEN (fare_amount#13202 > 0.0) THEN (tip_amount#13205 / fare_amount#13202) END AS tip_rate#13278]
#                                        :     :  +- PhotonProject [cast(trip_distance#13037 as double) AS trip_distance#13199, cast(PULocationID#13040 as int) AS PULocationID#13214, cast(DOLocationID#13041 as int) AS DOLocationID#13217, cast(fare_amount#13043 as double) AS fare_amount#13202, cast(tip_amount#13046 as double) AS tip_amount#13205, cast(total_amount#13049 as double) AS total_amount#13208, hour(cast(tpep_pickup_datetime#13034 as timestamp), Some(Etc/UTC)) AS pickup_hour#13274]
#                                        :     :     +- PhotonFilter (((((((((((isnotnull(tpep_dropoff_datetime#13035) AND isnotnull(tpep_pickup_datetime#13034)) AND isnotnull(trip_distance#13037)) AND isnotnull(passenger_count#13036)) AND isnotnull(total_amount#13049)) AND (cast(passenger_count#13036 as int) >= 1)) AND (cast(passenger_count#13036 as int) <= 6)) AND (cast(trip_distance#13037 as double) >= 0.2)) AND (cast(trip_distance#13037 as double) <= 50.0)) AND (cast(total_amount#13049 as double) > 0.0)) AND ((cast((cast(cast(tpep_dropoff_datetime#13035 as timestamp) as bigint) - cast(cast(tpep_pickup_datetime#13034 as timestamp) as bigint)) as double) / 60.0) >= 1.0)) AND ((cast((cast(cast(tpep_dropoff_datetime#13035 as timestamp) as bigint) - cast(cast(tpep_pickup_datetime#13034 as timestamp) as bigint)) as double) / 60.0) <= 180.0))
#                                        :     :        +- PhotonRowToColumnar
#                                        :     :           +- FileScan csv [tpep_pickup_datetime#13034,tpep_dropoff_datetime#13035,passenger_count#13036,trip_distance#13037,PULocationID#13040,DOLocationID#13041,fare_amount#13043,tip_amount#13046,total_amount#13049] Batched: false, DataFilters: [isnotnull(tpep_dropoff_datetime#13035), isnotnull(tpep_pickup_datetime#13034), isnotnull(trip_di..., Format: CSV, Location: InMemoryFileIndex(36 paths)[dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_201..., PartitionFilters: [], PushedFilters: [IsNotNull(tpep_dropoff_datetime), IsNotNull(tpep_pickup_datetime), IsNotNull(trip_distance), IsN..., ReadSchema: struct<tpep_pickup_datetime:string,tpep_dropoff_datetime:string,passenger_count:string,trip_dista...
#                                        :     +- PhotonShuffleExchangeSource
#                                        :        +- PhotonShuffleMapStage EXECUTOR_BROADCAST, [id=#17749]
#                                        :           +- PhotonShuffleExchangeSink SinglePartition
#                                        :              +- PhotonProject [LocationID#13145 AS PULocationID#13331, Borough#13146 AS Borough_name#13169]
#                                        :                 +- PhotonFilter isnotnull(LocationID#13145)
#                                        :                    +- PhotonRowToColumnar
#                                        :                       +- FileScan csv [LocationID#13145,Borough#13146] Batched: false, DataFilters: [isnotnull(LocationID#13145)], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/databricks-datasets/nyctaxi/taxizone], PartitionFilters: [], PushedFilters: [IsNotNull(LocationID)], ReadSchema: struct<LocationID:string,Borough:string>
#                                        +- PhotonShuffleExchangeSource
#                                           +- PhotonShuffleMapStage EXECUTOR_BROADCAST, [id=#17762]
#                                              +- PhotonShuffleExchangeSink SinglePartition
#                                                 +- PhotonProject [LocationID#13336 AS DOLocationID#13335]
#                                                    +- PhotonFilter isnotnull(LocationID#13336)
#                                                       +- PhotonRowToColumnar
#                                                          +- FileScan csv [LocationID#13336] Batched: false, DataFilters: [isnotnull(LocationID#13336)], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/databricks-datasets/nyctaxi/taxizone], PartitionFilters: [], PushedFilters: [IsNotNull(LocationID)], ReadSchema: struct<LocationID:string>
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

tip_by_boro = (
    df_joined.groupBy("PU_Borough")
    .agg(F.avg("tip_rate").alias("avg_tip_rate"), F.count("*").alias("trips"))
    .orderBy(F.desc("avg_tip_rate"))
)
tip_by_boro.show()

peak_hour = (
    df_clean.groupBy("pickup_hour")
    .count()
    .orderBy(F.desc("count"))
)
peak_hour.show(5)

avg_dist_pairs = (
    df_joined.groupBy("PU_Borough", "DO_Borough")
    .agg(F.avg("trip_distance").alias("avg_distance"), F.count("*").alias("trips"))
    .filter("trips >= 5000")
    .orderBy(F.desc("avg_distance"))
)
avg_dist_pairs.show(10)
# Out:
# +--------------------+--------------------+---------+
# |          PU_Borough|        avg_tip_rate|    trips|
# +--------------------+--------------------+---------+
# |         Credit card|    6.89351151545218|     4307|
# |                 EWR|    6.89351151545218|     4307|
# |       Standard Rate|    6.89351151545218|     4307|
# |             Unknown|   0.206932773625666|  3736058|
# |               Bronx|   0.192775586906355|   308943|
# |         Voided trip| 0.19024551733576173|      729|
# |          Group ride| 0.19024551733576167|      729|
# |              Queens| 0.16113235073694462| 18547394|
# |           Manhattan| 0.16086570303507508|270720743|
# |                Cash| 0.14109757672825113|      290|
# |                 JFK| 0.14109757672825113|      290|
# |Nassau or Westche...| 0.13741292244672712|   663869|
# |             Dispute| 0.13741292244672706|   663869|
# |            Brooklyn| 0.13185189101940958|  3680216|
# |       Staten Island| 0.09630268628105244|     6510|
# |              Newark|0.029596760416612293|     3118|
# |           No Charge|0.029596760416612293|     3118|
# |     Negotiated fare|0.008967206024135104|      435|
# +--------------------+--------------------+---------+
#
# +-----------+--------+
# |pickup_hour|   count|
# +-----------+--------+
# |         18|18741874|
# |         19|18133826|
# |         17|16683252|
# |         20|16603243|
# |         21|16480723|
# +-----------+--------+
# only showing top 5 rows
# +----------+-------------+------------------+------+
# |PU_Borough|   DO_Borough|      avg_distance| trips|
# +----------+-------------+------------------+------+
# |    Queens|Standard Rate| 33.03745844131218| 15821|
# |    Queens|          EWR| 33.03745844131218| 15821|
# |    Queens|  Credit card|33.037458441312175| 15821|
# |    Queens|Staten Island| 26.89809403111177| 20121|
# |    Queens|      Unknown|19.516778428241963|321309|
# | Manhattan|Staten Island|19.250602516931867| 42671|
# |     Bronx|     Brooklyn| 18.75454584737707| 11571|
# | Manhattan|  Credit card|17.583997590261802|532008|
# | Manhattan|          EWR|  17.5839975902618|532008|
# | Manhattan|Standard Rate|  17.5839975902618|532008|
# +----------+-------------+------------------+------+
# only showing top 10 rows

# %% [markdown]
# # Step H: Write Results to Parquet

# %%
agg_df.show(20)
# Out:
# +----------+-----------+--------+------------------+------------------+-------------------+
# |PU_Borough|pickup_hour|   trips|         avg_miles|         avg_total|       avg_tip_rate|
# +----------+-----------+--------+------------------+------------------+-------------------+
# | Manhattan|         18|17482004| 2.136958465974506|15.192062065590234|0.16856183517145382|
# | Manhattan|         19|16903389|2.1567067219478986|14.799441652734169|0.16963685194799008|
# | Manhattan|         17|15394948| 2.226213928751183|15.833075497822092|0.16094658442483903|
# | Manhattan|         20|15339035| 2.310482299571011|14.582196747653878|0.17216770597667894|
# | Manhattan|         21|15143904|2.4475205647103944|14.911812764341487| 0.1697537024051325|
# | Manhattan|         14|14716392| 2.455025166494635|15.919868422170422| 0.1470033868378145|
# | Manhattan|         15|14592458| 2.390400012115867|15.798106106531106| 0.1482791990605973|
# | Manhattan|         22|14262112|2.5817350109156436|15.372424419274372|0.16945512197776516|
# | Manhattan|         13|14105841| 2.393113524390386| 15.63961773276423|0.14840857684412537|
# | Manhattan|         12|14067046|2.2968598133538634|15.259208877200146|0.14819354306752563|
# | Manhattan|         16|13392841| 2.343861166574005|16.244666659539327| 0.1575684333115927|
# | Manhattan|         11|13287264|2.2491193740110824|  14.9982659281306|0.14831096626764062|
# | Manhattan|          9|12690558|2.1985585038892714|14.710579182522332|0.15977755658346832|
# | Manhattan|         10|12618708|2.2014523800693446|14.698350222492813|0.15436900795521286|
# | Manhattan|          8|12467132|2.2616221990751484|14.679984787153643|0.16681752654969417|
# | Manhattan|         23|11466089|2.6947844134124677|15.462447335745004|0.16720386477052238|
# | Manhattan|          7|10022217| 2.457270234719534|14.369846824277325|0.16669094426089348|
# | Manhattan|          0| 8397248|2.8028791349261195| 15.42318164590959|0.16882846734370924|
# | Manhattan|          1| 6056260| 2.874059470696444|15.377091123888878|0.17035055574666388|
# | Manhattan|          6| 5871225| 2.990742012101401|15.428321493383057|0.15277750067819262|
# +----------+-----------+--------+------------------+------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# Due to serverless environment restrictions, results were not persisted to DBFS, but displayed in the notebook output instead.
